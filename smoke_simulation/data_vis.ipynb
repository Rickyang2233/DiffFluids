# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.12) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
data = np.load('/media/bamf-big/gefan/DiffFluids/data/smoke/res64x64_dt1_t100_nsrc256.npz', allow_pickle=True)

# %%
density = data['density']
velocity = data['velocity']
condition = data['param']

# %%
sample = density[5000:5000+64, ...]
grid = torchvision.utils.make_grid(torch.from_numpy(sample).unsqueeze(1), nrow=8, padding=2, normalize=False, pad_value=1.0)
plt.figure(figsize=(20, 20))
plt.imshow(grid.detach().numpy()[0, ...], cmap='gray', origin='lower')
plt.axis('off')
# Out:
# (-0.5, 529.5, -0.5, 529.5)
